# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from typing import List
import os

# %%
AvaBuildLand = pd.read_csv("Ava_Streets_Table.csv")
AvaBuildLand.head()
# Out:
#    Unnamed: 0                      A_Properties  \
# 0           1            3000 S 28TH ST
# 1           2            3102 S 28TH ST
# 2           3  3200 S 28TH ST, UNIT 101
# 3           4  3200 S 28TH ST, UNIT 102
# 4           5  3200 S 28TH ST, UNIT 201
#
#                                      A_Current_Owner  A_Account_Num  A_SQFT
# 0           \r\r\n\t\t\t\t\t\tCITY OF ALEXANDRIA\t\t       50299410       1
# 1  \r\r\n\t\t\t\t\t\tALEXANDRIA REDEVELOPMENTHOUS...       50299400       1
# 2  \r\r\n\t\t\t\t\t\tBEGUM SAIRAKHALEK MOHAMMAD A...       50466800    1090
# 3  \r\r\n\t\t\t\t\t\tCHESLEY JOHN W III AND JUDIT...       50466810    1280
# 4  \r\r\n\t\t\t\t\t\tSILVA HUGO TRNEGRONI ANDREA ...       50466820     700

# %%
AvaBuildingLand = pd.read_csv("ABuildingLand.csv")
AvaBuildingLand
# Out:
#         Unnamed: 0       Num A_Levy_Year    A_Land_Value A_Building_Value  \
# 0                1  50299410     01/2025  $1,375,389               $0
# 1                2  50299410     01/2024  $1,375,389               $0
# 2                3  50299410     01/2023  $1,375,389               $0
# 3                4  50299410     01/2022  $1,375,389               $0
# 4                5  50299410     01/2021  $1,375,389               $0
# ...            ...       ...         ...             ...              ...
# 981399      981400  26312030     01/2004    $373,800         $410,000
# 981400      981401  26312030     01/2003    $287,500         $416,400
# 981401      981402  26312030     01/2002    $230,000         $422,800
# 981402      981403  26312030     01/2001    $200,000         $363,800
# 981403      981404  26312030     01/2000    $175,000         $281,700
#
#          A_Total_Value  A_Zip_Code
# 0       $1,375,389           22313
# 1       $1,375,389           22313
# ...

# %%
AvaBuildingLand.columns
# Out:
# Index(['Unnamed: 0', 'Num', 'A_Levy_Year', 'A_Land_Value', 'A_Building_Value',
#        'A_Total_Value', 'A_Zip_Code'],
#       dtype='object')

# %%
ABLCopy = AvaBuildingLand.copy()
ABLCopy = ABLCopy.rename(columns = {"Unnamed: 0": "Property Record", "Num": "Account Number", "A_Levy_Year": "Levy Year",
                      "A_Land_Value": "Land Value", "A_Building_Value": "Building Value", "A_Total_Value": "Total Value", "A_Zip_Code": "Zip Code"}
          )
ABLCopy.head()
# Out:
#    Property Record  Account Number Levy Year      Land Value Building Value  \
# 0                1        50299410   01/2025  $1,375,389             $0
# 1                2        50299410   01/2024  $1,375,389             $0
# 2                3        50299410   01/2023  $1,375,389             $0
# 3                4        50299410   01/2022  $1,375,389             $0
# 4                5        50299410   01/2021  $1,375,389             $0
#
#       Total Value  Zip Code
# 0  $1,375,389         22313
# 1  $1,375,389         22313
# 2  $1,375,389         22313
# 3  $1,375,389         22313
# 4  $1,375,389         22313

# %%
ABLCopy = ABLCopy.set_index("Property Record")
ABLCopy.head()
# Out:
#                  Account Number Levy Year      Land Value Building Value  \
# Property Record
# 1                      50299410   01/2025  $1,375,389             $0
# 2                      50299410   01/2024  $1,375,389             $0
# 3                      50299410   01/2023  $1,375,389             $0
# 4                      50299410   01/2022  $1,375,389             $0
# 5                      50299410   01/2021  $1,375,389             $0
#
#                     Total Value  Zip Code
# Property Record
# 1                $1,375,389         22313
# 2                $1,375,389         22313
# 3                $1,375,389         22313
# 4                $1,375,389         22313
# 5                $1,375,389         22313

# %%
ABLCopy.dtypes
# Out:
# Account Number     int64
# Levy Year         object
# Land Value        object
# Building Value    object
# Total Value       object
# Zip Code           int64
# dtype: object

# %%
def extract_value(df, columns: List[str]):
    for column in columns:
        df[column] = df[column].str.extract("(\d{1,3}(?:,\d{3})*|\d+)")
        df[column] = df[column].str.replace(",", "")
        df[column] = df[column].astype(float)
        df[column] = df[column].astype(int)

    return df

# %%
value_columns = ["Land Value", "Building Value", "Total Value"]
ABLCopy = extract_value(ABLCopy, value_columns)

# %%
ABLCopy.head()
# Out:
#                  Account Number Levy Year  Land Value  Building Value  \
# Property Record
# 1                      50299410   01/2025     1375389               0
# 2                      50299410   01/2024     1375389               0
# 3                      50299410   01/2023     1375389               0
# 4                      50299410   01/2022     1375389               0
# 5                      50299410   01/2021     1375389               0
#
#                  Total Value  Zip Code
# Property Record
# 1                    1375389     22313
# 2                    1375389     22313
# 3                    1375389     22313
# 4                    1375389     22313
# 5                    1375389     22313

# %%
ABLCopy[ABLCopy['Account Number'] == 50467490].head()
# Out:
#                  Account Number Levy Year  Land Value  Building Value  \
# Property Record
# 1847                   50467490   01/2025       86036          160214
# 1848                   50467490   01/2024       86036          149783
# 1849                   50467490   01/2023       80323          139837
# 1850                   50467490   01/2022       76498          133178
# 1851                   50467490   01/2021       76498          133178
#
#                  Total Value  Zip Code
# Property Record
# 1847                  246250      6410
# 1848                  235819      6410
# 1849                  220160      6410
# 1850                  209676      6410
# 1851                  209676      6410

# %% [markdown]
# Write a function that will essentailly replace the invalid zip code, with the correct one, only if the first column above and below match are are also valid zip codes!!!

# %%
ABLCopy['Levy Year'] = ABLCopy['Levy Year'].astype(str)
ABLCopy['Levy Year'] = ABLCopy['Levy Year'].str.replace("01/", "")
ABLCopy['Levy Year'] = ABLCopy['Levy Year'].str.extract(r'(\d{4})')
ABLCopy['Levy Year'] = ABLCopy['Levy Year'].astype(float)
ABLCopy['Levy Year'] = ABLCopy['Levy Year'].astype(int)
ABLCopy.head()
# Out:
#                  Account Number  Levy Year  Land Value  Building Value  \
# Property Record
# 1                      50299410       2025     1375389               0
# 2                      50299410       2024     1375389               0
# 3                      50299410       2023     1375389               0
# 4                      50299410       2022     1375389               0
# 5                      50299410       2021     1375389               0
#
#                  Total Value  Zip Code
# Property Record
# 1                    1375389     22313
# 2                    1375389     22313
# 3                    1375389     22313
# 4                    1375389     22313
# 5                    1375389     22313

# %%
ABLCopy.dtypes
# Out:
# Account Number    int64
# Levy Year         int32
# Land Value        int32
# Building Value    int32
# Total Value       int32
# Zip Code          int64
# dtype: object

# %%
valid_zip_codes = [22312, 22311, 22302, 22206, 22304, 22305, 22301, 22314]

ValidZipABL = ABLCopy[ABLCopy['Zip Code'].isin(valid_zip_codes)]
ValidZipABL.head()
# Out:
#                  Account Number  Levy Year  Land Value  Building Value  \
# Property Record
# 27                     50299400       2025     3031482         1364125
# 28                     50299400       2024     3031482         1364125
# 29                     50299400       2023     3031482         1364125
# 30                     50299400       2022     3031482         1364125
# 31                     50299400       2021     3031482         1364125
#
#                  Total Value  Zip Code
# Property Record
# 27                   4395607     22314
# 28                   4395607     22314
# 29                   4395607     22314
# 30                   4395607     22314
# 31                   4395607     22314

# %%
ValidZipABL.to_csv("ValidZipCodeData.csv", index = False)

# %%
folder_name = "Alexandria Personal Project"
os.makedirs(folder_name, exist_ok=True)
file_path = os.path.join(folder_name, "ValidZipCodeData.csv")
ValidZipABL.to_csv(file_path, index=False)
print(f"CSV saved to :{file_path}")
# Out:
# CSV saved to :Alexandria Personal Project\ValidZipCodeData.csv

# %%
len(ValidZipABL)
# Out:
# 812332

# %%
NonValidZipABL = ABLCopy[~ABLCopy['Zip Code'].isin(valid_zip_codes)]
NonValidZipABL.head()
# Out:
#                  Account Number  Levy Year  Land Value  Building Value  \
# Property Record
# 1                      50299410       2025     1375389               0
# 2                      50299410       2024     1375389               0
# 3                      50299410       2023     1375389               0
# 4                      50299410       2022     1375389               0
# 5                      50299410       2021     1375389               0
#
#                  Total Value  Zip Code
# Property Record
# 1                    1375389     22313
# 2                    1375389     22313
# 3                    1375389     22313
# 4                    1375389     22313
# 5                    1375389     22313

# %%
len(ValidZipABL)
# Out:
# 823226

# %%
ABLCopy_ZipGroup = ABLCopy.groupby(["Zip Code"]).agg({"Levy Year": list, "Land Value": list, "Building Value": list, "Total Value": list, "Account Number": list})
ABLCopy_ZipGroup.head()
# Out:
#                                                   Levy Year  \
# Zip Code
# 694       [2025, 2024, 2023, 2022, 2021, 2020, 2019, 201...
# 908       [2025, 2024, 2023, 2022, 2021, 2020, 2019, 201...
# 918       [2025, 2024, 2023, 2022, 2021, 2020, 2019, 201...
# 927       [2025, 2024, 2023, 2022, 2021, 2020, 2019, 201...
# 936       [2025, 2024, 2023, 2022, 2021, 2020, 2019, 201...
#
#                                                  Land Value  \
# Zip Code
# 694       [85947, 83850, 83850, 82206, 79045, 71859, 677...
# 908       [1970709, 1876865, 1770628, 1735910, 1685349, ...
# 918       [112878, 111484, 111484, 109298, 121442, 10747...
# 927       [102606, 96716, 95286, 90749, 87259, 84717, 79...
# 936       [195534, 181050, 177500, 177500, 177500, 17750...
#
#                                              Building Value  \
# Zip Code
# 694       [170639, 151000, 140478, 137723, 132426, 12038...
# 908       [1866524, 1771642, 1646352, 1615800, 1571307, ...
# ...

# %%
ValidZipABL_ZipGroup = ValidZipABL.groupby(["Zip Code", "Levy Year"]).agg({"Land Value": list, "Building Value": list, "Total Value": list, "Account Number": list})
ValidZipABL_ZipGroup.head()
# Out:
#                                                            Land Value  \
# Zip Code Levy Year
# 22206    2000       [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
#          2001       [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
#          2002       [31500, 0, 31000, 31000, 31000, 31500, 28600, ...
#          2003       [52100, 0, 51200, 51200, 51200, 52100, 47300, ...
#          2004       [67700, 0, 66600, 66600, 66600, 67700, 61500, ...
#
#                                                        Building Value  \
# Zip Code Levy Year
# 22206    2000       [110100, 0, 108800, 108800, 108800, 110100, 10...
#          2001       [124200, 0, 122700, 122700, 122700, 124200, 11...
#          2002       [157000, 0, 155100, 155100, 155100, 157000, 14...
#          2003       [200100, 0, 197700, 197700, 197700, 200100, 18...
#          2004       [222300, 0, 219600, 219600, 219600, 222300, 20...
#
#                                                           Total Value  \
# ...

# %%
ZipCode_22206 = ValidZipABL_ZipGroup.loc[22206]
ZipCode_22206.head()
# Out:
#                                                   Land Value  \
# Levy Year
# 2000       [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 2001       [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 2002       [31500, 0, 31000, 31000, 31000, 31500, 28600, ...
# 2003       [52100, 0, 51200, 51200, 51200, 52100, 47300, ...
# 2004       [67700, 0, 66600, 66600, 66600, 67700, 61500, ...
#
#                                               Building Value  \
# Levy Year
# 2000       [110100, 0, 108800, 108800, 108800, 110100, 10...
# 2001       [124200, 0, 122700, 122700, 122700, 124200, 11...
# 2002       [157000, 0, 155100, 155100, 155100, 157000, 14...
# 2003       [200100, 0, 197700, 197700, 197700, 200100, 18...
# 2004       [222300, 0, 219600, 219600, 219600, 222300, 20...
#
#                                                  Total Value  \
# Levy Year
# 2000       [140100, 0, 138300, 138300, 138300, 140100, 12...
# 2001       [154200, 0, 152200, 152200, 152200, 154200, 14...
# ...

# %%
ZipCode_22206 = ZipCode_22206.reset_index()
ZipCode_22206.head()
# Out:
#    Levy Year                                         Land Value  \
# 0       2000  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 1       2001  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 2       2002  [31500, 0, 31000, 31000, 31000, 31500, 28600, ...
# 3       2003  [52100, 0, 51200, 51200, 51200, 52100, 47300, ...
# 4       2004  [67700, 0, 66600, 66600, 66600, 67700, 61500, ...
#
#                                       Building Value  \
# 0  [110100, 0, 108800, 108800, 108800, 110100, 10...
# 1  [124200, 0, 122700, 122700, 122700, 124200, 11...
# 2  [157000, 0, 155100, 155100, 155100, 157000, 14...
# 3  [200100, 0, 197700, 197700, 197700, 200100, 18...
# 4  [222300, 0, 219600, 219600, 219600, 222300, 20...
#
#                                          Total Value  \
# 0  [140100, 0, 138300, 138300, 138300, 140100, 12...
# 1  [154200, 0, 152200, 152200, 152200, 154200, 14...
# 2  [188500, 0, 186100, 186100, 186100, 188500, 17...
# ...

# %%
ZipCode_22206['Total Value Sum'] = ZipCode_22206['Total Value'].apply(lambda x: sum(x))
ZipCode_22206['Average Total Value'] = ZipCode_22206['Total Value'].apply(lambda x: np.mean(x))
ZipCode_22206.head()
# Out:
#    Levy Year                                         Land Value  \
# 0       2000  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 1       2001  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 2       2002  [31500, 0, 31000, 31000, 31000, 31500, 28600, ...
# 3       2003  [52100, 0, 51200, 51200, 51200, 52100, 47300, ...
# 4       2004  [67700, 0, 66600, 66600, 66600, 67700, 61500, ...
#
#                                       Building Value  \
# 0  [110100, 0, 108800, 108800, 108800, 110100, 10...
# 1  [124200, 0, 122700, 122700, 122700, 124200, 11...
# 2  [157000, 0, 155100, 155100, 155100, 157000, 14...
# 3  [200100, 0, 197700, 197700, 197700, 200100, 18...
# 4  [222300, 0, 219600, 219600, 219600, 222300, 20...
#
#                                          Total Value  \
# 0  [140100, 0, 138300, 138300, 138300, 140100, 12...
# 1  [154200, 0, 152200, 152200, 152200, 154200, 14...
# 2  [188500, 0, 186100, 186100, 186100, 188500, 17...
# ...

# %%
plt.plot(ZipCode_22206['Levy Year'], ZipCode_22206['Average Total Value'])
plt.xlabel('Levy Year')
plt.ylabel('Average Total Value $')
plt.title('Average Total Value Over Levy Years')
plt.show()

# %%
unique_zip_codes = ValidZipABL_ZipGroup.index.get_level_values('Zip Code').unique()

total_value_sum_list = []
average_total_value_list = []

for zipcode in unique_zip_codes:
    CurrZipCode = ValidZipABL_ZipGroup.loc[zipcode]
    
    CurrZipCode = CurrZipCode.reset_index()
    
    total_value_sum = CurrZipCode['Total Value'].apply(lambda x: sum(x))
    average_total_value = CurrZipCode['Total Value'].apply(lambda x: np.mean(x))
    
    total_value_sum_list.extend(total_value_sum)
    average_total_value_list.extend(average_total_value)

ValidZipABL_ZipGroup = ValidZipABL_ZipGroup.reset_index()
ValidZipABL_ZipGroup['Total Value Sum'] = total_value_sum_list
ValidZipABL_ZipGroup['Average Total Value'] = average_total_value_list 
ValidZipABL_ZipGroup.head()
# Out:
#    Zip Code  Levy Year                                         Land Value  \
# 0     22206       2000  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 1     22206       2001  [30000, 0, 29500, 29500, 29500, 30000, 27200, ...
# 2     22206       2002  [31500, 0, 31000, 31000, 31000, 31500, 28600, ...
# 3     22206       2003  [52100, 0, 51200, 51200, 51200, 52100, 47300, ...
# 4     22206       2004  [67700, 0, 66600, 66600, 66600, 67700, 61500, ...
#
#                                       Building Value  \
# 0  [110100, 0, 108800, 108800, 108800, 110100, 10...
# 1  [124200, 0, 122700, 122700, 122700, 124200, 11...
# 2  [157000, 0, 155100, 155100, 155100, 157000, 14...
# 3  [200100, 0, 197700, 197700, 197700, 200100, 18...
# 4  [222300, 0, 219600, 219600, 219600, 222300, 20...
#
#                                          Total Value  \
# 0  [140100, 0, 138300, 138300, 138300, 140100, 12...
# 1  [154200, 0, 152200, 152200, 152200, 154200, 14...
# ...

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(
    data=ValidZipABL_ZipGroup, 
    x='Levy Year', 
    y='Average Total Value', 
    hue='Zip Code', 
    marker='o', 
    palette='tab10'
)

plt.xlabel('Levy Year')
plt.ylabel('Average Total Value')
plt.title('Average Total Value Over Time by Zip Code')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
